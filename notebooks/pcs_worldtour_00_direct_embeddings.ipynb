# %%
import pandas as pd
import numpy as np

results_file_name = '../data/pcs_worldtour_results.csv'
results = pd.read_csv(results_file_name, index_col = 0)
results['points'] = results.groupby('race_url').pcs_points.transform(lambda x: x / x.max())
results['one_day'] = results['race_url'].str.count('/') == 2

def extract_stage_number(race_url):
    if 'stage-' in race_url:
        return int(race_url.split('stage-')[1])
    elif 'prologue' in race_url:
        return 0
    else: # One-day race
        return -1

results['stage'] = results.race_url.apply(extract_stage_number)
results['race_url'] = results['race_url'].str.replace('/stage-.*|/prologue', '', regex = True)

races = pd.read_csv('../data/pcs_worldtour_races.csv')
riders = pd.read_csv('../data/pcs_worldtour_riders.csv', index_col = 0)
results = pd.merge(results, races)
results = pd.merge(results, riders)

results['race_id'] = np.where(
    results['one_day'],
    results['race_name'],
    results['race_url'].str.replace('race/', '') + '/' + results['stage'].astype(str)
)

results = results.dropna()

# Identify riders with 5 or more UCI points
points_per_rider = results.groupby('rider_name')['uci_points'].sum().sort_values()
riders_to_keep = points_per_rider[points_per_rider >= 5].index.values

results
# Out:
#             rider_url                 team_url   rank status  age     time  \
# 0       arnaud-demare                 fdj-2016    1.0     DF   24  6:54:45
# 1       arnaud-demare                 fdj-2016    5.0     DF   24  5:55:23
# 3       arnaud-demare                 fdj-2016   34.0     DF   24  4:54:45
# 5       arnaud-demare                 fdj-2017   20.0     DF   25  4:57:50
# 6       arnaud-demare                 fdj-2017    6.0     DF   25  7:08:44
# ...               ...                      ...    ...    ...  ...      ...
# 170302   vojtech-repa  equipo-kern-pharma-2022   57.0     DF   22  3:52:47
# 170303   vojtech-repa  equipo-kern-pharma-2022   78.0     DF   22  5:13:41
# 170304   vojtech-repa  equipo-kern-pharma-2022  121.0     DF   22  3:34:39
# 170305   vojtech-repa  equipo-kern-pharma-2022  110.0     DF   22  5:13:32
# 170306   vojtech-repa  equipo-kern-pharma-2022  108.0     DF   22  2:28:22
#
#         pcs_points  uci_points                         race_url    points  \
# 0              275       500.0         race/milano-sanremo/2016  1.000000
# 1               80       225.0          race/gent-wevelgem/2016  0.355556
# 3                5         8.0     race/cyclassics-hamburg/2016  0.022222
# 5               15        20.0  race/omloop-het-nieuwsblad/2017  0.066667
# 6               90       175.0         race/milano-sanremo/2017  0.327273
# ...            ...         ...                              ...       ...
# 170302           0         0.0        race/vuelta-a-espana/2022  0.000000
# 170303           0         0.0        race/vuelta-a-espana/2022  0.000000
# 170304           0         0.0        race/vuelta-a-espana/2022  0.000000
# 170305           0         0.0        race/vuelta-a-espana/2022  0.000000
# 170306           0         0.0        race/vuelta-a-espana/2022  0.000000
#
#         one_day  stage              race_name  year  stage_race  \
# 0          True     -1         milano-sanremo  2016       False
# 1          True     -1          gent-wevelgem  2016       False
# 3          True     -1     cyclassics-hamburg  2016       False
# 5          True     -1  omloop-het-nieuwsblad  2017       False
# 6          True     -1         milano-sanremo  2017       False
# ...         ...    ...                    ...   ...         ...
# 170302    False     17        vuelta-a-espana  2022        True
# 170303    False     18        vuelta-a-espana  2022        True
# 170304    False     19        vuelta-a-espana  2022        True
# 170305    False     20        vuelta-a-espana  2022        True
# 170306    False     21        vuelta-a-espana  2022        True
#
#            rider_name nationality                  race_id
# 0       DÉMARE Arnaud          FR           milano-sanremo
# 1       DÉMARE Arnaud          FR            gent-wevelgem
# 3       DÉMARE Arnaud          FR       cyclassics-hamburg
# 5       DÉMARE Arnaud          FR    omloop-het-nieuwsblad
# 6       DÉMARE Arnaud          FR           milano-sanremo
# ...               ...         ...                      ...
# 170302   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/17
# 170303   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/18
# 170304   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/19
# 170305   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/20
# 170306   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/21
#
# [159582 rows x 18 columns]

# %%
from tensorflow.keras.layers import StringLookup, Embedding, Flatten, ReLU, Dot
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import set_random_seed
from tensorflow.keras.activations import sigmoid

set_random_seed(42)
K = 5

riders = Input(shape = (1,), dtype = 'string', name = 'rider')
rider_name_to_int = StringLookup(vocabulary = riders_to_keep, name = 'rider_name_to_int')
rider_ints = rider_name_to_int(riders)
rider_vector = Embedding(rider_name_to_int.vocabulary_size(), K, name = 'rider_encoder')(rider_ints)
rider_vector_flat = Flatten(name = 'rider_vector')(rider_vector)

races = Input(shape = (1,), dtype = 'string', name = 'race')
race_id_to_int = StringLookup(vocabulary = results['race_id'].unique(), name = 'race_id_to_int')
race_ints = race_id_to_int(races)
race_vector = Embedding(race_id_to_int.vocabulary_size(), K, name = 'race_encoder')(race_ints)
race_vector_flat = Flatten(name = 'race_vector')(race_vector)

dot_product = Dot(axes = (1, 1), name = 'dot_product')([rider_vector_flat, race_vector_flat])
outputs = sigmoid(dot_product)

model = Model([riders, races], outputs)
model.summary()
# Out:
# 2023-04-28 23:43:45.584122: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  rider (InputLayer)             [(None, 1)]          0           []
#
#  race (InputLayer)              [(None, 1)]          0           []
#
#  rider_name_to_int (StringLooku  (None, 1)           0           ['rider[0][0]']
#  p)
#
#  race_id_to_int (StringLookup)  (None, 1)            0           ['race[0][0]']
#
#  rider_encoder (Embedding)      (None, 1, 5)         4855        ['rider_name_to_int[0][0]']
#
#  race_encoder (Embedding)       (None, 1, 5)         4865        ['race_id_to_int[0][0]']
#
#  rider_vector (Flatten)         (None, 5)            0           ['rider_encoder[0][0]']
#
#  race_vector (Flatten)          (None, 5)            0           ['race_encoder[0][0]']
#
#  dot_product (Dot)              (None, 1)            0           ['rider_vector[0][0]',
#                                                                   'race_vector[0][0]']
#
#  tf.math.sigmoid (TFOpLambda)   (None, 1)            0           ['dot_product[0][0]']
#
# ==================================================================================================
# Total params: 9,720
# Trainable params: 9,720
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = "adam", loss = "binary_crossentropy")
history = model.fit([results.rider_name, results.race_id], results.points, epochs=75, verbose = 1)
# Out:
# Epoch 1/75
# 4987/4987 [==============================] - 9s 2ms/step - loss: 0.3660
# Epoch 2/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.1102
# Epoch 3/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0992
# Epoch 4/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0979
# Epoch 5/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0976
# Epoch 6/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0975
# Epoch 7/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0974
# Epoch 8/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0974
# Epoch 9/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0974
# Epoch 10/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0972
# Epoch 11/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0971
# Epoch 12/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0969
# Epoch 13/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0965
# Epoch 14/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0959
# Epoch 15/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0952
# Epoch 16/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0941
# Epoch 17/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0930
# Epoch 18/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0918
# Epoch 19/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0905
# Epoch 20/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0894
# Epoch 21/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0883
# Epoch 22/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0874
# Epoch 23/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0864
# Epoch 24/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0856
# Epoch 25/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0849
# Epoch 26/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0842
# Epoch 27/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0835
# Epoch 28/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0829
# Epoch 29/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0823
# Epoch 30/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0818
# Epoch 31/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0813
# Epoch 32/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0808
# Epoch 33/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0804
# Epoch 34/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0800
# Epoch 35/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0796
# Epoch 36/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0793
# Epoch 37/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0789
# Epoch 38/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0786
# Epoch 39/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0783
# Epoch 40/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0780
# Epoch 41/75
# 4987/4987 [==============================] - 9s 2ms/step - loss: 0.0778
# Epoch 42/75
# 4987/4987 [==============================] - 9s 2ms/step - loss: 0.0776
# Epoch 43/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0773
# Epoch 44/75
# 4987/4987 [==============================] - 9s 2ms/step - loss: 0.0771
# Epoch 45/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0769
# Epoch 46/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0768
# Epoch 47/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0766
# Epoch 48/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0764
# Epoch 49/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0763
# Epoch 50/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0761
# Epoch 51/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0760
# Epoch 52/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0758
# Epoch 53/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0757
# Epoch 54/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0756
# Epoch 55/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0755
# Epoch 56/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0753
# Epoch 57/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0752
# Epoch 58/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0751
# Epoch 59/75
# 4987/4987 [==============================] - 9s 2ms/step - loss: 0.0750
# Epoch 60/75
# 4987/4987 [==============================] - 9s 2ms/step - loss: 0.0750
# Epoch 61/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0749
# Epoch 62/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0748
# Epoch 63/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0747
# Epoch 64/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0746
# Epoch 65/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0745
# Epoch 66/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0744
# Epoch 67/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0743
# Epoch 68/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0743
# Epoch 69/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0742
# Epoch 70/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0742
# Epoch 71/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0741
# Epoch 72/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0740
# Epoch 73/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0740
# Epoch 74/75
# 4987/4987 [==============================] - 9s 2ms/step - loss: 0.0739
# Epoch 75/75
# 4987/4987 [==============================] - 8s 2ms/step - loss: 0.0738

# %%
model.save('../models/pcs_worldtour_direct_embeddings')
# Out:
# INFO:tensorflow:Assets written to: ../models/pcs_worldtour_direct_embeddings/assets
