# %%
import pandas as pd
import numpy as np

results_file_name = '../data/pcs_worldtour_results.csv'
results = pd.read_csv(results_file_name, index_col = 0)
results['points'] = results.groupby('race_url').pcs_points.transform(lambda x: x / x.max())
results['one_day'] = results['race_url'].str.count('/') == 2

def extract_stage_number(race_url):
    if 'stage-' in race_url:
        return int(race_url.split('stage-')[1])
    elif 'prologue' in race_url:
        return 0
    else: # One-day race
        return -1

results['stage'] = results.race_url.apply(extract_stage_number)
results['race_url'] = results['race_url'].str.replace('/stage-.*|/prologue', '', regex = True)

races = pd.read_csv('../data/pcs_worldtour_races.csv')
riders = pd.read_csv('../data/pcs_worldtour_riders.csv', index_col = 0)
results = pd.merge(results, races)
results = pd.merge(results, riders)

results['race_id'] = np.where(
    results['one_day'],
    results['race_name'],
    results['race_url'].str.replace('race/', '') + '/' + results['stage'].astype(str)
)

results = results.dropna()

# Identify riders with 25 or more PCS points
points_per_rider = results.groupby('rider_name')['pcs_points'].sum().sort_values()
riders_to_keep = points_per_rider[points_per_rider >= 25].index.values

results
# Out:
#             rider_url                 team_url   rank status  age     time  \
# 0       arnaud-demare                 fdj-2016    1.0     DF   24  6:54:45
# 1       arnaud-demare                 fdj-2016    5.0     DF   24  5:55:23
# 3       arnaud-demare                 fdj-2016   34.0     DF   24  4:54:45
# 5       arnaud-demare                 fdj-2017   20.0     DF   25  4:57:50
# 6       arnaud-demare                 fdj-2017    6.0     DF   25  7:08:44
# ...               ...                      ...    ...    ...  ...      ...
# 170120   vojtech-repa  equipo-kern-pharma-2022   57.0     DF   22  3:52:47
# 170121   vojtech-repa  equipo-kern-pharma-2022   78.0     DF   22  5:13:41
# 170122   vojtech-repa  equipo-kern-pharma-2022  121.0     DF   22  3:34:39
# 170123   vojtech-repa  equipo-kern-pharma-2022  110.0     DF   22  5:13:32
# 170124   vojtech-repa  equipo-kern-pharma-2022  108.0     DF   22  2:28:22
#
#         pcs_points  uci_points                         race_url profile_icon  \
# 0              275       500.0         race/milano-sanremo/2016           p2
# 1               80       225.0          race/gent-wevelgem/2016           p2
# 3                5         8.0     race/cyclassics-hamburg/2016           p0
# 5               15        20.0  race/omloop-het-nieuwsblad/2017           p2
# 6               90       175.0         race/milano-sanremo/2017           p2
# ...            ...         ...                              ...          ...
# 170120           0         0.0        race/vuelta-a-espana/2022           p1
# 170121           0         0.0        race/vuelta-a-espana/2022           p5
# 170122           0         0.0        race/vuelta-a-espana/2022           p4
# 170123           0         0.0        race/vuelta-a-espana/2022           p4
# 170124           0         0.0        race/vuelta-a-espana/2022           p1
#
#         profile_score    points  one_day  stage              race_name  year  \
# 0                64.0  1.000000     True     -1         milano-sanremo  2016
# 1                31.0  0.355556     True     -1          gent-wevelgem  2016
# 3                33.0  0.022222     True     -1     cyclassics-hamburg  2016
# 5                33.0  0.066667     True     -1  omloop-het-nieuwsblad  2017
# 6                65.0  0.327273     True     -1         milano-sanremo  2017
# ...               ...       ...      ...    ...                    ...   ...
# 170120          161.0  0.000000    False     17        vuelta-a-espana  2022
# 170121          214.0  0.000000    False     18        vuelta-a-espana  2022
# 170122          101.0  0.000000    False     19        vuelta-a-espana  2022
# 170123          216.0  0.000000    False     20        vuelta-a-espana  2022
# 170124           10.0  0.000000    False     21        vuelta-a-espana  2022
#
#         stage_race     rider_name nationality                  race_id
# 0            False  DÉMARE Arnaud          FR           milano-sanremo
# 1            False  DÉMARE Arnaud          FR            gent-wevelgem
# 3            False  DÉMARE Arnaud          FR       cyclassics-hamburg
# 5            False  DÉMARE Arnaud          FR    omloop-het-nieuwsblad
# 6            False  DÉMARE Arnaud          FR           milano-sanremo
# ...            ...            ...         ...                      ...
# 170120        True   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/17
# 170121        True   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/18
# 170122        True   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/19
# 170123        True   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/20
# 170124        True   ŘEPA Vojtěch          CZ  vuelta-a-espana/2022/21
#
# [159406 rows x 20 columns]

# %%
from tensorflow.keras.layers import StringLookup, Embedding, Flatten, ReLU, Dot
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import set_random_seed
from tensorflow.keras.activations import sigmoid

set_random_seed(42)
K = 5

riders = Input(shape = (1,), dtype = 'string', name = 'rider')
rider_name_to_int = StringLookup(vocabulary = riders_to_keep, name = 'rider_name_to_int')
rider_ints = rider_name_to_int(riders)
rider_vector = Embedding(rider_name_to_int.vocabulary_size(), K, name = 'rider_encoder')(rider_ints)
rider_vector_flat = Flatten(name = 'rider_vector')(rider_vector)

races = Input(shape = (1,), dtype = 'string', name = 'race')
race_id_to_int = StringLookup(vocabulary = results['race_id'].unique(), name = 'race_id_to_int')
race_ints = race_id_to_int(races)
race_vector = Embedding(race_id_to_int.vocabulary_size(), K, name = 'race_encoder')(race_ints)
race_vector_flat = Flatten(name = 'race_vector')(race_vector)

dot_product = Dot(axes = (1, 1), name = 'dot_product')([rider_vector_flat, race_vector_flat])
outputs = sigmoid(dot_product)

model = Model([riders, races], outputs)
model.summary()
# Out:
# 2023-05-11 22:47:56.762144: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  rider (InputLayer)             [(None, 1)]          0           []
#
#  race (InputLayer)              [(None, 1)]          0           []
#
#  rider_name_to_int (StringLooku  (None, 1)           0           ['rider[0][0]']
#  p)
#
#  race_id_to_int (StringLookup)  (None, 1)            0           ['race[0][0]']
#
#  rider_encoder (Embedding)      (None, 1, 5)         4790        ['rider_name_to_int[0][0]']
#
#  race_encoder (Embedding)       (None, 1, 5)         4860        ['race_id_to_int[0][0]']
#
#  rider_vector (Flatten)         (None, 5)            0           ['rider_encoder[0][0]']
#
#  race_vector (Flatten)          (None, 5)            0           ['race_encoder[0][0]']
#
#  dot_product (Dot)              (None, 1)            0           ['rider_vector[0][0]',
#                                                                   'race_vector[0][0]']
#
#  tf.math.sigmoid (TFOpLambda)   (None, 1)            0           ['dot_product[0][0]']
#
# ==================================================================================================
# Total params: 9,650
# Trainable params: 9,650
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = "adam", loss = "bce")
history = model.fit([results.rider_name, results.race_id], results.points, epochs=100, verbose = 1)
# Out:
# Epoch 1/100
# 4982/4982 [==============================] - 9s 2ms/step - loss: 0.3812
# Epoch 2/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.1101
# Epoch 3/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0986
# Epoch 4/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0972
# Epoch 5/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0970
# Epoch 6/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0969
# Epoch 7/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0969
# Epoch 8/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0968
# Epoch 9/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0967
# Epoch 10/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0965
# Epoch 11/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0961
# Epoch 12/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0956
# Epoch 13/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0948
# Epoch 14/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0938
# Epoch 15/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0928
# Epoch 16/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0917
# Epoch 17/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0905
# Epoch 18/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0894
# Epoch 19/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0884
# Epoch 20/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0874
# Epoch 21/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0864
# Epoch 22/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0855
# Epoch 23/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0846
# Epoch 24/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0838
# Epoch 25/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0831
# Epoch 26/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0824
# Epoch 27/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0818
# Epoch 28/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0812
# Epoch 29/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0807
# Epoch 30/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0801
# Epoch 31/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0797
# Epoch 32/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0792
# Epoch 33/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0788
# Epoch 34/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0785
# Epoch 35/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0781
# Epoch 36/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0778
# Epoch 37/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0775
# Epoch 38/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0772
# Epoch 39/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0770
# Epoch 40/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0767
# Epoch 41/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0765
# Epoch 42/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0763
# Epoch 43/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0760
# Epoch 44/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0758
# Epoch 45/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0757
# Epoch 46/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0755
# Epoch 47/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0753
# Epoch 48/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0752
# Epoch 49/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0750
# Epoch 50/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0749
# Epoch 51/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0748
# Epoch 52/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0746
# Epoch 53/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0746
# Epoch 54/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0744
# Epoch 55/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0743
# Epoch 56/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0742
# Epoch 57/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0741
# Epoch 58/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0740
# Epoch 59/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0739
# Epoch 60/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0738
# Epoch 61/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0737
# Epoch 62/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0737
# Epoch 63/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0736
# Epoch 64/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0735
# Epoch 65/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0734
# Epoch 66/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0734
# Epoch 67/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0733
# Epoch 68/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0732
# Epoch 69/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0732
# Epoch 70/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0731
# Epoch 71/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0730
# Epoch 72/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0730
# Epoch 73/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0730
# Epoch 74/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0729
# Epoch 75/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0728
# Epoch 76/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0728
# Epoch 77/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0728
# Epoch 78/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0727
# Epoch 79/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0726
# Epoch 80/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0727
# Epoch 81/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0725
# Epoch 82/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0725
# Epoch 83/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0725
# Epoch 84/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0725
# Epoch 85/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0724
# Epoch 86/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0724
# Epoch 87/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0723
# Epoch 88/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0723
# Epoch 89/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0723
# Epoch 90/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0723
# Epoch 91/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0722
# Epoch 92/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0723
# Epoch 93/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0722
# Epoch 94/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0721
# Epoch 95/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0721
# Epoch 96/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0721
# Epoch 97/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0720
# Epoch 98/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0720
# Epoch 99/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0720
# Epoch 100/100
# 4982/4982 [==============================] - 8s 2ms/step - loss: 0.0720

# %%
model.save('../models/pcs_worldtour_direct_embeddings')
# Out:
# INFO:tensorflow:Assets written to: ../models/pcs_worldtour_direct_embeddings/assets
